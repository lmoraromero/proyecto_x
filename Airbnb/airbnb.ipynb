# %%
import pandas as pd

# %%
listings = pd.read_csv('listings.csv')
listings.head()
# Out:
#        id                                name    host_id host_name  \
# 0   21853                Bright and airy room      83531     Abdel
# 1  204570  Lovely 110m2 home - Best location!    1004721      Alex
# 2   24805              Gran Via Studio Madrid  346366726    Alvaro
# 3  205199                     Tafari Gran Via    1008659     Nuria
# 4  209373   Attic in the Heart of Madrid-WIFI    1031664      José
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0              Latina      Cármenes  40.40381   -3.74130     Private room
# 1              Centro        Cortes  40.41520   -3.69668  Entire home/apt
# 2              Centro   Universidad  40.42183   -3.70529  Entire home/apt
# 3              Centro   Universidad  40.42116   -3.70384  Entire home/apt
# 4              Centro   Embajadores  40.41126   -3.70347     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
listings[['host_id', 'host_name']].value_counts()
# Out:
# host_id    host_name
# 377605855  MIT House       300
# 291253690  Fran Y Marta    296
# 346367515  Ukio            260
# 518713670  Bemadrid        216
# 434208714  Blueground      188
#                           ...
# 81562865   Ejessie           1
# 81577110   Ruben             1
# 81582599   Alberto           1
# 81617490   Anastasio         1
# 567968941  Victor            1
# Length: 12571, dtype: int64

# %%
barrio = pd.read_csv('neighbourhoods.csv')
barrio.head()
# Out:
#   neighbourhood_group neighbourhood
# 0          Arganzuela       Acacias
# 1          Arganzuela        Atocha
# 2          Arganzuela       Chopera
# 3          Arganzuela      Delicias
# 4          Arganzuela      Imperial

# %%
reviews = pd.read_csv('reviews.csv')
reviews.head()
# Out:
#    listing_id        date
# 0       21853  2014-10-10
# 1       21853  2014-10-13
# 2       21853  2014-11-09
# 3       21853  2014-11-11
# 4       21853  2014-11-16
